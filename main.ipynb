# %%
import GeneticAlgorithm.GeneticAlgorithm as ga
from tools.City import representation
from tools.functions import *

# %% [markdown]
# ## Simple problem instance

# %%
# Set model parameters
popSize = 10
crossoverRate = 0.9
mutationRate = 0.5
num_iter = 3*int(1e3)

# %%
# Load cities and compute the distance matrix
cities = create(10, 10)

showCities(cities)
EDM = computeEDM(cities)

# Permutation representation of our phenotype (cities)
chromosome = representation(cities)

# %%
# Instanciate our model
genAlg = ga.GeneticAlgorithm(chromosome, popSize, crossoverRate, mutationRate, num_iter, show = True)

# %%
# Run our Genetic Algorithm model
fittest, bestFitness = genAlg.run(EDM)

# %%
# Show solution
showPath(fittest, 'path1')

# %%
# Show some statistics
genAlg.showStats()
# Out:
# The mean best fitness (MBF) is: 22.97071153590152

# %% [markdown]
# ## Complex problem instance

# %%
# Set model parameters
popSize = 100
crossoverRate = 0.9
mutationRate = 0.5
num_iter = 3*int(1e3)

# %%
# Load cities and compute the distance matrix
cities = create(100, 10)

showCities(cities)
EDM = computeEDM(cities)

# Permutation representation of our phenotype (cities)
chromosome = representation(cities)

# %%
# Instanciate our model
genAlg = ga.GeneticAlgorithm(chromosome, popSize, crossoverRate, mutationRate, num_iter, show = True)
# Run our Genetic Algorithm model
fittest, bestFitness = genAlg.run(EDM)

# %%
# Show solution
showPath(fittest, 'path2')

# %%
# Show some statistics
genAlg.showStats()
# Out:
# The mean best fitness (MBF) is: 175.4492844824243
